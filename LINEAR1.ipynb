# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url="https://github.com/TAWFIK813/TawfikShebli/blob/main/AMES_Final_DF.csv?raw=true"

# %%
df = pd.read_csv(url,index_col=0)

# %%
df
# Out:
#               Lot Area  Overall Qual  Overall Cond  Year Built  \
# Lot Frontage
# 141.000000       31770             6             5        1960
# 80.000000        11622             5             6        1961
# 81.000000        14267             6             6        1958
# 93.000000        11160             7             5        1968
# 74.000000        13830             5             5        1997
# ...                ...           ...           ...         ...
# 37.000000         7937             6             6        1984
# 75.144444         8885             5             5        1983
# 62.000000        10441             5             5        1992
# 77.000000        10010             5             5        1974
# 74.000000         9627             7             5        1993
#
#               Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  BsmtFin SF 2  \
# Lot Frontage
# 141.000000              1960         112.0         639.0           0.0
# 80.000000               1961           0.0         468.0         144.0
# 81.000000               1958         108.0         923.0           0.0
# 93.000000               1968           0.0        1065.0           0.0
# 74.000000               1998           0.0         791.0           0.0
# ...                      ...           ...           ...           ...
# 37.000000               1984           0.0         819.0           0.0
# 75.144444               1983           0.0         301.0         324.0
# 62.000000               1992           0.0         337.0           0.0
# 77.000000               1975           0.0        1071.0         123.0
# 74.000000               1994          94.0         758.0           0.0
#
#               Bsmt Unf SF  Total Bsmt SF  ...  Sale Type_ConLw  Sale Type_New  \
# Lot Frontage                              ...
# 141.000000          441.0         1080.0  ...                0              0
# 80.000000           270.0          882.0  ...                0              0
# 81.000000           406.0         1329.0  ...                0              0
# 93.000000          1045.0         2110.0  ...                0              0
# 74.000000           137.0          928.0  ...                0              0
# ...                   ...            ...  ...              ...            ...
# 37.000000           184.0         1003.0  ...                0              0
# 75.144444           239.0          864.0  ...                0              0
# 62.000000           575.0          912.0  ...                0              0
# 77.000000           195.0         1389.0  ...                0              0
# 74.000000           238.0          996.0  ...                0              0
#
#               Sale Type_Oth  Sale Type_VWD  Sale Type_WD   \
# Lot Frontage
# 141.000000                0              0              1
# 80.000000                 0              0              1
# 81.000000                 0              0              1
# 93.000000                 0              0              1
# 74.000000                 0              0              1
# ...                     ...            ...            ...
# 37.000000                 0              0              1
# 75.144444                 0              0              1
# 62.000000                 0              0              1
# 77.000000                 0              0              1
# 74.000000                 0              0              1
#
#               Sale Condition_AdjLand  Sale Condition_Alloca  \
# Lot Frontage
# 141.000000                         0                      0
# 80.000000                          0                      0
# 81.000000                          0                      0
# 93.000000                          0                      0
# 74.000000                          0                      0
# ...                              ...                    ...
# 37.000000                          0                      0
# 75.144444                          0                      0
# 62.000000                          0                      0
# 77.000000                          0                      0
# 74.000000                          0                      0
#
#               Sale Condition_Family  Sale Condition_Normal  \
# Lot Frontage
# 141.000000                        0                      1
# 80.000000                         0                      1
# 81.000000                         0                      1
# 93.000000                         0                      1
# 74.000000                         0                      1
# ...                             ...                    ...
# 37.000000                         0                      1
# 75.144444                         0                      1
# 62.000000                         0                      1
# 77.000000                         0                      1
# 74.000000                         0                      1
#
#               Sale Condition_Partial
# Lot Frontage
# 141.000000                         0
# 80.000000                          0
# 81.000000                          0
# 93.000000                          0
# 74.000000                          0
# ...                              ...
# 37.000000                          0
# 75.144444                          0
# 62.000000                          0
# 77.000000                          0
# 74.000000                          0
#
# [2925 rows x 273 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2925 entries, 141.0 to 74.0
# Columns: 273 entries, Lot Area to Sale Condition_Partial
# dtypes: float64(10), int64(263)
# memory usage: 6.1 MB

# %%
#we will prdict the house price given any house specs

# %%
X = df.drop('SalePrice',axis=1)
y = df['SalePrice']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=101)
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet
base_elastic_model = ElasticNet()
param_grid = {'alpha':[0.1,1,5,10,50,100],
              'l1_ratio':[.1, .5, .7, .9, .95, .99, 1]}

# %%
from sklearn.model_selection import GridSearchCV
grid_model = GridSearchCV(estimator=base_elastic_model,
                          param_grid=param_grid,
                          scoring='neg_mean_squared_error',
                          cv=5,
                          verbose=1)

# %%
grid_model.fit(scaled_X_train,y_train)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.385e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.666e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.313e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.983e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.546e+11, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.230e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.366e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.563e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.885e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.600e+11, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.544e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.635e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.086e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.079e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.561e+11, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.497e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.590e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.065e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.032e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.690e+11, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.986e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.115e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.433e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.473e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.527e+11, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.613e+11, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.840e+11, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.873e+11, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.989e+11, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.215e+09, tolerance: 1.346e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.511e+09, tolerance: 1.355e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.894e+09, tolerance: 1.308e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.507e+09, tolerance: 1.415e+09
#   model = cd_fast.enet_coordinate_descent(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.737e+09, tolerance: 1.438e+09
#   model = cd_fast.enet_coordinate_descent(
# GridSearchCV(cv=5, estimator=ElasticNet(),
#              param_grid={'alpha': [0.1, 1, 5, 10, 50, 100],
#                          'l1_ratio': [0.1, 0.5, 0.7, 0.9, 0.95, 0.99, 1]},
#              scoring='neg_mean_squared_error', verbose=1)

# %%
y_pred = grid_model.predict(scaled_X_test)
from sklearn.metrics import mean_absolute_error,mean_squared_error
mean_absolute_error(y_test,y_pred)
np.sqrt(mean_squared_error(y_test,y_pred))
np.mean(df['SalePrice'])
# Out:
# 180815.53743589742
